# %% [markdown]
# <a href="https://colab.research.google.com/github/awchisholm/snippets/blob/main/FreeKittens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from PIL import Image
from io import BytesIO

kitten = requests.get('https://placekitten.com/200/300')
img = Image.open(BytesIO(kitten.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0x7F3B94B5D350>
